# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Flatten, Dense


import csv

lines = []
with open('data/u/driving_log.csv') as csvfile:
    reader = csv.reader(csvfile)
    for line in reader:
        lines.append(line)
# Out:
# Using TensorFlow backend.

# %%
newline = np.delete(lines, 0, 0)

# %%
ex = cv2.imread(('data/u/'+'IMG/center_2016_12_01_13_30_48_287.jpg'))

plt.imshow(ex)
plt.show()
plt.imshow(cv2.flip(ex,1))
plt.show()
exn = ex[65:125,:]
plt.imshow(exn)
plt.show()
exnn = cv2.resize(exn,(160,30))
plt.imshow(exnn)
plt.show()

# %%
loss = [0.0183,0.0126,0.0109,0.0101,0.0092,0.0086,0.0081,0.0078,0.0074,0.0072]
val_loss=[0.0121,0.0104,0.0101,0.0093,0.0088,0.0092,0.0092,0.0102,0.0096,0.0096]

test_loss = 0.0114
plt.figure()
plt.plot(range(1,11),loss, label='Training loss')
plt.plot(range(1,11),val_loss, label='Validation loss')
plt.plot(range(1,11),np.full((10),test_loss), label='Test loss')
plt.ylim(ymin=0)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Mean Square Error', fontsize=12)
plt.title('Training loss', fontsize=16)
plt.show()
fig.savefig('loss.jpg')


loss = [0.0176,0.0126,0.0112,0.0102,0.0094]
val_loss=[0.0120,0.0110,0.0100,0.009,0.0089]

test_loss = 0.0081
plt.figure()
plt.plot(range(1,6),loss, label='Training loss')
plt.plot(range(1,6),val_loss, label='Validation loss')
plt.plot(range(1,6),np.full((5),test_loss), label='Test loss')
plt.ylim(ymin=0)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Mean Square Error', fontsize=12)
plt.title('Training loss', fontsize=16)
plt.show()
fig.savefig('lossnew.jpg')

# %%
iuc = []
iul = []
iur = []
mu = []

for line in newline:
    i = cv2.imread(('data/u/'+line[0]))
    iuc.append(i)
    m = float(line[3])
    mu.append(m)
    #il = cv2.imread(('data/u/'+line[1]))
    #iul.append(il)
    #ir = cv2.imread(('data/u/'+line[2]))
    #iur.append(ir)

# %%
x_train = np.array(iuc)
y_train = np.array(mu)

# %%
model = Sequential()
